# %%
for i in range(1,2):
    for j in range(1,2):
        print("10",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("11 12",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("13 14 15",end=" ")

    print("")
# Out:
# 10
# 11 12
# 13 14 15

# %%
for i in range(4,0,-1):
    for j in range(1,i+1):
        print("*",end=" ")

    print("")
# Out:
# * * * *
# * * *
# * *
# *

# %%
for i in range(1,2):
    for j in range(1,2):
        print("D",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("D C",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("D C B",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("D C B A",end=" ")
# Out:
# D
# D C
# D C B
# D C B A

# %%
for i in range(1,2):
    for j in range(1,2):
        print("10",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("10 11",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("10 11 12 ",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("10 11 12 13 ",end=" ")
# Out:
# 10
# 10 11
# 10 11 12
# 10 11 12 13

# %%
for i in range(1,2):
    for j in range(1,2):
        print("A",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("A B",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("A B C",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("A B C D",end=" ")
# Out:
# A
# A B
# A B C
# A B C D

# %%
for i in range(1,2):
    for j in range(1,2):
        print("D C B A",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("D C B",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("D C",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("D",end=" ")
# Out:
# D C B A
# D C B
# D C
# D

# %%
for i in range(1,2):
    for j in range(1,2):
        print("1",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("1 2",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("1 2 1",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("1 2 1 2",end=" ")
    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("1 2 1 2 1",end=" ")
# Out:
# 1
# 1 2
# 1 2 1
# 1 2 1 2
# 1 2 1 2 1

# %%
for i in range(1,2):
    for j in range(1,2):
        print("F",end=" ")
        print("")
        for i in range(1,2):
               for j in range(1,2):
                   print("H J",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("L N P",end=" ")

    print("")
    for i in range(1,2):
               for j in range(1,2):
                   print("R T V X",end=" ")
# Out:
# F
# H J
# L N P
# R T V X

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-5fa9af61e3db> in <cell line: 1>()
#       1 for i in range(4,0,-1):
# ----> 2     for s in range(s<=i):
#       3          for j in range(1,i+1):
#       4                print("*",end=" " )
#       5
#
# NameError: name 's' is not defined
